# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\OFFICE INFO\Desktop\python\titanic.csv')
print(df)
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
print (df.isnull().sum().sum())
# Out:
# 3869

# %%
print(df.isnull().sum())
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
print(df['cabin'].head())
# Out:
# 0         B5
# 1    C22 C26
# 2    C22 C26
# 3    C22 C26
# 4    C22 C26
# Name: cabin, dtype: object

# %%
print(df['body'].head())
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3    135.0
# 4      NaN
# Name: body, dtype: float64

# %%
df['pclass'].fillna(df['pclass'].mean(), inplace = True)

# %%
df['survived'].fillna(df['survived'].median(), inplace = True)

# %%
df['sibsp'].fillna(df['sibsp'].mean(), inplace = True)

# %%
df['age'].fillna(df['age'].median(), inplace = True)

# %%
df['fare'].fillna(df['fare'].median(), inplace = True)

# %%
df['body'].fillna(df['body'].mean(), inplace = True)

# %%
df['parch'].fillna(df['parch'].median(), inplace= True)

# %%
print(df.isnull().sum())
# Out:
# pclass          0
# survived        0
# name            1
# sex             1
# age             0
# sibsp           0
# parch           0
# ticket          1
# fare            0
# cabin        1015
# embarked        3
# boat          824
# body            0
# home.dest     565
# dtype: int64

# %%
print(len(df['name']))
# Out:
# 1310

# %%
print(df['name'].value_counts())
# Out:
# Connolly, Miss. Kate                                   2
# Kelly, Mr. James                                       2
# Mallet, Master. Andre                                  1
# Waelens, Mr. Achille                                   1
# Sandstrom, Miss. Marguerite Rut                        1
#                                                       ..
# Nosworthy, Mr. Richard Cater                           1
# Burns, Miss. Mary Delia                                1
# Thomson, Mr. Alexander Morrison                        1
# Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengtsson)    1
# Keefe, Mr. Arthur                                      1
# Name: name, Length: 1307, dtype: int64

# %%
df['name'].fillna('Connolly, Miss. Kate', inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate     NaN  28.0  0.498854
#
#       parch  ticket     fare cabin embarked boat        body home.dest
# 1305    0.0    2665  14.4542   NaN        C  NaN  160.809917       NaN
# 1306    0.0    2656   7.2250   NaN        C  NaN  304.000000       NaN
# 1307    0.0    2670   7.2250   NaN        C  NaN  160.809917       NaN
# 1308    0.0  315082   7.8750   NaN        S  NaN  160.809917       NaN
# 1309    0.0     NaN  14.4542   NaN      NaN  NaN  160.809917       NaN

# %%
print(len(df['sex']))
# Out:
# 1310

# %%
print(df['sex'].value_counts())
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df['sex'].fillna('male' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch  ticket     fare cabin embarked boat        body home.dest
# 1305    0.0    2665  14.4542   NaN        C  NaN  160.809917       NaN
# 1306    0.0    2656   7.2250   NaN        C  NaN  304.000000       NaN
# 1307    0.0    2670   7.2250   NaN        C  NaN  160.809917       NaN
# 1308    0.0  315082   7.8750   NaN        S  NaN  160.809917       NaN
# 1309    0.0     NaN  14.4542   NaN      NaN  NaN  160.809917       NaN

# %%
print(len(df['ticket']))
# Out:
# 1310

# %%
print(df['ticket'].value_counts())
# Out:
# CA. 2343             11
# 1601                  8
# CA 2144               8
# PC 17608              7
# 347082                7
#                      ..
# 113801                1
# STON/O 2. 3101285     1
# 234818                1
# 345781                1
# A/S 2816              1
# Name: ticket, Length: 929, dtype: int64

# %%
df['ticket'].fillna('CA. 2343' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch    ticket     fare cabin embarked boat        body home.dest
# 1305    0.0      2665  14.4542   NaN        C  NaN  160.809917       NaN
# 1306    0.0      2656   7.2250   NaN        C  NaN  304.000000       NaN
# 1307    0.0      2670   7.2250   NaN        C  NaN  160.809917       NaN
# 1308    0.0    315082   7.8750   NaN        S  NaN  160.809917       NaN
# 1309    0.0  CA. 2343  14.4542   NaN      NaN  NaN  160.809917       NaN

# %%
print(len(df['cabin']))
# Out:
# 1310

# %%
print(df['cabin'].value_counts())
# Out:
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F2                 4
# D                  4
#                   ..
# E68                1
# D6                 1
# F E69              1
# B10                1
# E52                1
# Name: cabin, Length: 186, dtype: int64

# %%
df['cabin'].fillna('C23 C25 C27' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch    ticket     fare        cabin embarked boat        body  \
# 1305    0.0      2665  14.4542  C23 C25 C27        C  NaN  160.809917
# 1306    0.0      2656   7.2250  C23 C25 C27        C  NaN  304.000000
# 1307    0.0      2670   7.2250  C23 C25 C27        C  NaN  160.809917
# 1308    0.0    315082   7.8750  C23 C25 C27        S  NaN  160.809917
# 1309    0.0  CA. 2343  14.4542  C23 C25 C27      NaN  NaN  160.809917
#
#      home.dest
# 1305       NaN
# 1306       NaN
# 1307       NaN
# 1308       NaN
# ...

# %%
print(len(df['embarked']))
# Out:
# 1310

# %%
print(df['embarked'].value_counts ())
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
df['embarked'].fillna('S' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch    ticket     fare        cabin embarked boat        body  \
# 1305    0.0      2665  14.4542  C23 C25 C27        C  NaN  160.809917
# 1306    0.0      2656   7.2250  C23 C25 C27        C  NaN  304.000000
# 1307    0.0      2670   7.2250  C23 C25 C27        C  NaN  160.809917
# 1308    0.0    315082   7.8750  C23 C25 C27        S  NaN  160.809917
# 1309    0.0  CA. 2343  14.4542  C23 C25 C27        S  NaN  160.809917
#
#      home.dest
# 1305       NaN
# 1306       NaN
# 1307       NaN
# 1308       NaN
# ...

# %%
print(len(df['home.dest']))
# Out:
# 1310

# %%
print(df['home.dest'].value_counts())
# Out:
# New York, NY                    64
# London                          14
# Montreal, PQ                    10
# Paris, France                    9
# Cornwall / Akron, OH             9
#                                 ..
# London / Winnipeg, MB            1
# Hartford, Huntingdonshire        1
# Brennes, Norway New York         1
# London New York, NY              1
# Portugal / Sau Paulo, Brazil     1
# Name: home.dest, Length: 369, dtype: int64

# %%
df['home.dest'].fillna('New York, NY' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch    ticket     fare        cabin embarked boat        body  \
# 1305    0.0      2665  14.4542  C23 C25 C27        C  NaN  160.809917
# 1306    0.0      2656   7.2250  C23 C25 C27        C  NaN  304.000000
# 1307    0.0      2670   7.2250  C23 C25 C27        C  NaN  160.809917
# 1308    0.0    315082   7.8750  C23 C25 C27        S  NaN  160.809917
# 1309    0.0  CA. 2343  14.4542  C23 C25 C27        S  NaN  160.809917
#
#          home.dest
# 1305  New York, NY
# 1306  New York, NY
# 1307  New York, NY
# ...

# %%
print(len(df['boat']))
# Out:
# 1310

# %%
print(df['boat'].value_counts())
# Out:
# 13         39
# C          38
# 15         37
# 14         33
# 4          31
# 10         29
# 5          27
# 3          26
# 9          25
# 11         25
# 8          23
# 7          23
# 16         23
# 6          20
# D          20
# 12         19
# 2          13
# A          11
# B           9
# 1           5
# 5 7         2
# C D         2
# 13 15       2
# 13 15 B     1
# 5 9         1
# 8 10        1
# 15 16       1
# Name: boat, dtype: int64

# %%
df['boat'].fillna('13' , inplace = True)
df.tail()
# Out:
#         pclass  survived                       name     sex   age     sibsp  \
# 1305  3.000000       0.0      Zabour, Miss. Thamine  female  28.0  1.000000
# 1306  3.000000       0.0  Zakarian, Mr. Mapriededer    male  26.5  0.000000
# 1307  3.000000       0.0        Zakarian, Mr. Ortin    male  27.0  0.000000
# 1308  3.000000       0.0         Zimmerman, Mr. Leo    male  29.0  0.000000
# 1309  2.294882       0.0       Connolly, Miss. Kate    male  28.0  0.498854
#
#       parch    ticket     fare        cabin embarked boat        body  \
# 1305    0.0      2665  14.4542  C23 C25 C27        C   13  160.809917
# 1306    0.0      2656   7.2250  C23 C25 C27        C   13  304.000000
# 1307    0.0      2670   7.2250  C23 C25 C27        C   13  160.809917
# 1308    0.0    315082   7.8750  C23 C25 C27        S   13  160.809917
# 1309    0.0  CA. 2343  14.4542  C23 C25 C27        S   13  160.809917
#
#          home.dest
# 1305  New York, NY
# 1306  New York, NY
# 1307  New York, NY
# ...

# %%
print(df.isnull().sum())
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1310 non-null   float64
#  1   survived   1310 non-null   float64
#  2   name       1310 non-null   object
#  3   sex        1310 non-null   object
#  4   age        1310 non-null   float64
#  5   sibsp      1310 non-null   float64
#  6   parch      1310 non-null   float64
#  7   ticket     1310 non-null   object
#  8   fare       1310 non-null   float64
#  9   cabin      1310 non-null   object
#  10  embarked   1310 non-null   object
#  11  boat       1310 non-null   object
#  12  body       1310 non-null   float64
#  13  home.dest  1310 non-null   object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
df['ticket'].values
# Out:
# array(['24160', '113781', '113781', ..., '2670', '315082', 'CA. 2343'],
#       dtype=object)

# %%
df['boat'].values
# Out:
# array(['2', '11', '13', ..., '13', '13', '13'], dtype=object)

# %%
df['cabin'].values
# Out:
# array(['B5', 'C22 C26', 'C22 C26', ..., 'C23 C25 C27', 'C23 C25 C27',
#        'C23 C25 C27'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['name'] = encoder.fit_transform(df['name'])
df
# Out:
#         pclass  survived  name     sex      age     sibsp  parch    ticket  \
# 0     1.000000       1.0    21  female  29.0000  0.000000    0.0     24160
# 1     1.000000       1.0    23    male   0.9167  1.000000    2.0    113781
# 2     1.000000       0.0    24  female   2.0000  1.000000    2.0    113781
# 3     1.000000       0.0    25    male  30.0000  1.000000    2.0    113781
# 4     1.000000       0.0    26  female  25.0000  1.000000    2.0    113781
# ...        ...       ...   ...     ...      ...       ...    ...       ...
# 1305  3.000000       0.0  1292  female  28.0000  1.000000    0.0      2665
# 1306  3.000000       0.0  1293    male  26.5000  0.000000    0.0      2656
# 1307  3.000000       0.0  1294    male  27.0000  0.000000    0.0      2670
# 1308  3.000000       0.0  1295    male  29.0000  0.000000    0.0    315082
# 1309  2.294882       0.0   261    male  28.0000  0.498854    0.0  CA. 2343
#
#           fare        cabin embarked boat        body  \
# ...

# %%
df['sex'] = encoder.fit_transform(df['sex'])

# %%
df['cabin'] = encoder.fit_transform(df['cabin'])

# %%
df['boat'] = encoder.fit_transform(df['boat'])

# %%
df['embarked'] = encoder.fit_transform(df['embarked'])

# %%
df['ticket'] = encoder.fit_transform (df['ticket'])

# %%
df['home.dest'] = encoder.fit_transform (df['home.dest'])

# %%
df
# Out:
#         pclass  survived  name  sex      age     sibsp  parch  ticket  \
# 0     1.000000       1.0    21    0  29.0000  0.000000    0.0     187
# 1     1.000000       1.0    23    1   0.9167  1.000000    2.0      49
# 2     1.000000       0.0    24    0   2.0000  1.000000    2.0      49
# 3     1.000000       0.0    25    1  30.0000  1.000000    2.0      49
# 4     1.000000       0.0    26    0  25.0000  1.000000    2.0      49
# ...        ...       ...   ...  ...      ...       ...    ...     ...
# 1305  3.000000       0.0  1292    0  28.0000  1.000000    0.0     259
# 1306  3.000000       0.0  1293    1  26.5000  0.000000    0.0     250
# 1307  3.000000       0.0  1294    1  27.0000  0.000000    0.0     264
# 1308  3.000000       0.0  1295    1  29.0000  0.000000    0.0     346
# 1309  2.294882       0.0   261    1  28.0000  0.498854    0.0     778
#
#           fare  cabin  embarked  boat        body  home.dest
# 0     211.3375     43         2    11  160.809917        308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1310 non-null   float64
#  1   survived   1310 non-null   float64
#  2   name       1310 non-null   int32
#  3   sex        1310 non-null   int32
#  4   age        1310 non-null   float64
#  5   sibsp      1310 non-null   float64
#  6   parch      1310 non-null   float64
#  7   ticket     1310 non-null   int32
#  8   fare       1310 non-null   float64
#  9   cabin      1310 non-null   int32
#  10  embarked   1310 non-null   int32
#  11  boat       1310 non-null   int32
#  12  body       1310 non-null   float64
#  13  home.dest  1310 non-null   int32
# dtypes: float64(7), int32(7)
# memory usage: 107.6 KB

# %%
import seaborn as sns

# %%
new_data = df.drop(['cabin' ,'body' , 'boat' , 'embarked' , 'fare' , 'parch' , 'sibsp'] , axis = 1)
sns.boxplot( data = new_data)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
new_data ['pclass'] = scaler.fit_transform(new_data [['pclass']].values)
new_data ['survived'] = scaler.fit_transform(new_data [['survived']].values)
new_data ['name'] = scaler.fit_transform(new_data [['name']].values)
new_data ['sex'] = scaler.fit_transform(new_data [['sex']].values)
new_data ['age'] = scaler.fit_transform(new_data [['age']].values)
new_data ['ticket'] = scaler.fit_transform(new_data [['ticket']].values)
new_data ['home.dest'] = scaler.fit_transform(new_data [['home.dest']].values)
sns.boxplot( data = new_data)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.corr()
df = df[['age','sex','survived']]
sns.pairplot(df, kind="scatter")
plt.show()

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )

# %%
import pandas as pd
df[['pclass'] , ['survived']].groupby (['survived'] , as_index = True ).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-349ac3b7866d> in <module>
#       1 import pandas as pd
# ----> 2 df[['pclass'] , ['survived']].groupby (['survived'] , as_index = True ).mean()
#
# ~\.conda\New folder\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\.conda\New folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# ...
